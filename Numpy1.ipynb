# %%
import csv
import pandas as pd

# %%
train_data = pd.read_csv('./train.csv')
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data[['Name', 'Age', 'Ticket']]
# Out:
#                                                   Name   Age            Ticket
# 0                              Braund, Mr. Owen Harris  22.0         A/5 21171
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0          PC 17599
# 2                               Heikkinen, Miss. Laina  26.0  STON/O2. 3101282
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0            113803
# 4                             Allen, Mr. William Henry  35.0            373450
# ..                                                 ...   ...               ...
# 886                              Montvila, Rev. Juozas  27.0            211536
# 887                       Graham, Miss. Margaret Edith  19.0            112053
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN        W./C. 6607
# 889                              Behr, Mr. Karl Howell  26.0            111369
# 890                                Dooley, Mr. Patrick  32.0            370376
#
# [891 rows x 3 columns]

# %%
train_data.loc[:,'Name' : 'Ticket']
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket
# ...

# %%
train_data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train_data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
## P =2 성 = 남 생존 = 0
train_data[(train_data['Pclass']==2)&(train_data['Sex']=='male')&(train_data['Survived']==0)].head(3)
# Out:
#     PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 20           21         0       2        Fynney, Mr. Joseph J  male  35.0
# 33           34         0       2       Wheadon, Mr. Edward H  male  66.0
# 70           71         0       2  Jenkin, Mr. Stephen Curnow  male  32.0
#
#     SibSp  Parch      Ticket  Fare Cabin Embarked
# 20      0      0      239865  26.0   NaN        S
# 33      0      0  C.A. 24579  10.5   NaN        S
# 70      0      0  C.A. 33111  10.5   NaN        S

# %%
##groupby() : 기준 성, fair id count 몇명?
train_data.groupby(by='Sex')[['Fare','PassengerId']].count()
# Out:
#         Fare  PassengerId
# Sex
# female   314          314
# male     577          577

# %%
train_data.groupby(by='Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
a = pd.read_csv('./1997_2018.csv',encoding='cp949')
a.describe()
# Out:
#                  년           서 울           경 기           강 원           충 북  \
# count    22.000000     22.000000     22.000000     22.000000     22.000000
# mean   2007.500000  54880.363636  87447.500000  17012.681818  16791.636364
# std       6.493587  14344.994171   6634.477291   2838.453710   1186.259409
# min    1997.000000  42468.000000  68154.000000  13722.000000  14429.000000
# 25%    2002.250000  46850.500000  84864.250000  14749.750000  16164.250000
# 50%    2007.500000  49318.000000  88418.500000  15870.500000  17059.500000
# 75%    2012.750000  54252.000000  91542.750000  19300.750000  17447.500000
# max    2018.000000  98871.000000  97240.000000  22799.000000  19496.000000
#
#                  충 남           전 북            전 남           경 북  \
# count      22.000000     22.000000      22.000000     22.000000
# mean   120256.500000  20060.727273  154335.818182  30050.000000
# std     37312.392649   2561.863090   21384.949885   3256.596807
# ...

# %%
a.head()
# Out:
#       년    서 울    경 기    강 원    충 북    충 남    전 북     전 남    경 북     경 남  \
# 0  1997  98871  94265  22799  19496  56417  25042  127607  36842  174623
# 1  1998  84342  68154  17631  14472  75713  18577  121763  29431   36085
# 2  1999  76835  78592  21454  16142  83149  21954  125396  34796   32113
# 3  2000  66664  82711  21204  17654  87754  23745  129791  33753   31287
# 4  2001  58400  85669  21197  18177  88877  23562  128152  34668   31832
#
#      부 산   제 주    대 구    인 천   광 주    대 전       울 산   세 종       합 계
# 0  43280  7305  21919  46377  8774  10283       NaN   NaN  793899.0
# 1  32632  5511  17612  27985  6412   8176  105782.0   NaN  670278.0
# 2  35758  6936  20831  29433  7148  10086  119034.0   NaN  719657.0
# 3  37925  7689  21275  33375  8209  12389  127131.0   NaN  742557.0
# 4  36949  8379  20031  45473  8509  10520  123273.0  0.12  743667.0

# %%
##1998년만 출력

# %%
a[a['년'].isin(['1998'])]
# Out:
#       년    서 울    경 기    강 원    충 북    충 남    전 북     전 남    경 북    경 남  \
# 1  1998  84342  68154  17631  14472  75713  18577  121763  29431  36085
#
#      부 산   제 주    대 구    인 천   광 주   대 전       울 산  세 종       합 계
# 1  32632  5511  17612  27985  6412  8176  105782.0  NaN  670278.0
